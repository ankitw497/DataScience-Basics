# %% [markdown]
# <div style="color:#006666; padding:0px 10px; border-radius:5px; font-size:18px;"><h1 style='margin:10px 5px'>Matplotlib Plots</h1>
# </div>
#
# © Copyright Machine Learning Plus

# %% [markdown]
# Topics
#
# 1. Matplotlib overview
#     - pyplot
#     - Add Color, Marker and Line to the plot
#     - Add Title, Legend, X and Y axis labels to the plot
#     - Modify the Axis Ticks Positions and Label
#     - Draw Subplots
#     - Add annotations to the plot
#     - Save plots
# 2. Plotting Correlation: Relationship between two numerical variables
#     - Scatterplot and lines of best fit (loess, lm)
#     - Correlation matrix with Heatmap
#
# 3. Plotting Distribution of Variables
#     - Histogram and Density plot
#     - Bar Plot, Stacked
#     - Box Plot and Violin Plot
#
# 3. Plotting Relationship between numerical vs categorical variable
#     - Multiple Box Plots
#     - Bubble Plots
#     - Pair Plots
#     - Trellis Chart or Facets
#
# 4. Plotting Relationship between Categorical vs Categorical variable
#     - Mosaic Plots
#
# 5. Plotting Time Series
#     - Line Plots
#     - Line Plots with multiple lines
#     - Line Plots with secondary axis
#     - Autocorrelation Plot
#     - Time Series Seasonal Plots
#         - Multi-Line chart
#         - The monthly and yearly box plot

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>1. Matplotlib Overview</h2>
# </div>

# %% [markdown]
# Matplotlib is the most popular plotting library in python. Using matplotlib, you can create pretty much any type of plot.
#
# It was created by John D. Hunter. It's a open source library and is mostly written in python. Some of the segments are written in C, objective-C and Javascript.
#
# You can access the scource code here (https://github.com/matplotlib/matplotlib)
#
# Let's jump to the implementations straight away and install matplotlib in the python environment

# %%
# pip install matplotlib==3.4.3

# %%
# Import matplotlib and check the version
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.4.3

# %% [markdown]
# Let's import few more libaries which will be used in coming sections

# %%
# Import libraries
import pandas as pd
import numpy as np
import random

import seaborn as sns

# %% [markdown]
# ## Pyplot - matplotlib.pyplot
#
# It is a collection of majority of the matplotlib utilities. It is the core object that contains the methods to create all sorts of charts and features in a plot.
#
# matplotlib.pyplot is usually imported as plt

# %%
# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# The %matplotlib inline is a jupyter notebook specific command that let’s you see the plots within the notebook itself.
#
# Let's create a simple plot using plot() function from pyplot module

# %%
plt.plot([1,2,3,4,10]);

# %% [markdown]
# I just gave a list of numbers to plt.plot() and it drew a line chart automatically. It assumed the values of the X-axis to start from zero going up to as many items in the data.
#
# Notice the line matplotlib.lines.Line2D in code output?
#
# That’s because Matplotlib returns the plot object itself besides drawing the plot.
#
# If you only want to see the plot, add plt.show() at the end and execute all the lines in one shot.
#
# What if you wish to draw a coloured scatterplot instead?
#
# ### Add Color, Marker and Line to the plot
#
# If you look at the arguments plt.plot() expects, you will see it expects 3 basic arguments in the following order: (x, y, format).
#
# You are well clear about x and y. Let's look at the last argument format. This format is a short hand combination of {color}{marker}{line}.
# The first placeholder in the format will get colour, followed by the marker followed by the line style.
#
# Let's understand it with help of an example.
#
# Let's say you wish to a line plot with dots and the colour should be green. You need to specify the format as 'go-'. The format 'go-' has 3 characters standing for: ‘green colored dots with solid line’.
#
# Let's draw it

# %%
# 'go-' stands for ‘green colored dots with solid line’.
plt.plot([1,2,3,4,5], [1,2,3,4,10], color="#0A0");
# plt.show()

# %% [markdown]
# Now let’s draw a scaterplot with greendots.
#
# By omitting the line part (‘-‘) in the end, you will be left with only green dots (‘go’), which makes it draw a scatterplot.

# %%
# 'go' stands for green dots
plt.plot([1,2,3,4,5], [1,2,3,4,10], 'go-')
plt.show()

# %% [markdown]
# Explicit the arguments

# %%
# More explicitly:
plt.plot([1,2,3,4,5], [1,2,3,4,10], color="g", marker="o", linestyle="-", markersize=10)
plt.show()

# %% [markdown]
# Few commonly used short hand format examples are:
# * 'r*--' : ‘red stars with dashed lines’
# * 'ks.' : ‘black squares with dotted line’ (‘k’ stands for black)
# * 'bD-.' : ‘blue diamonds with dash-dot line’.
#
# For a complete list of colors, markers and linestyles, check out the help(plt.plot) command.
#
# This plot looks empty. What if you wish to add title, legend and X and Y axis labels as well?

# %% [markdown]
# ### Add Title, Legend, X and Y axis labels to the plot
#
# Let's understand these concepts with an example.
#
# Example: You wish to analyze how the price of house in a locality are varying with area of the house.
#
# So let's create two lists of area and price

# %%
# list of area and price
area = [50, 90, 150, 200, 220, 250, 350, 500]
price = [400, 1000, 1300, 1900, 2200, 2400, 3570, 5100]

# %% [markdown]
# You can use the below commands:
# - plt.title() for title of the plot
# - plt.xlabel() for x label of the plot
# - plt.ylabel() for y label of the plot
# - plt.legend() for legend of the plot (legend text comes from the plot's label parameter)

# %%
plt.plot(area, price, 'go')

# %%
plt.plot(area, price, 'go', label = 'Locality A')
plt.title('Price vs Area Scatterplot')
plt.xlabel('Area of the house')
plt.ylabel('Price of the house')
plt.legend(loc='best')   # "Top Right", "Top Left", "Bottom Right", "Bottom Left"
plt.show()

# %% [markdown]
# __Plotting two sets of Points__

# %% [markdown]
# You must be thinking what's the use of legend. It is not making much sense here. Right?
#
# Don't worry let's take another example.
#
# Example: You wish to analyze how the price of house are varying with area of the house. But this time you have multiple localities

# %%
# list of area and price
area_loc1 = [50, 90, 150, 200, 220, 250, 350, 500]
price_loc1 = [400, 1000, 1300, 1900, 2200, 2400, 3570, 5100]

area_loc2 = [50, 90, 150, 200, 220, 250, 350, 500]
price_loc2 = [500, 1200, 1250, 2100, 2300, 2800, 3770, 6100]

# %% [markdown]
# Now let's draw the plot. Basically, you have to plot another set of points of different color in the same figure.
#
# Any idea how to do it?
#
# Simply call plt.plot() again, it will add those point to the same picture.
#
# You might wonder, why it does not draw these points in a new panel altogether? I will come to that in the coming sections.

# %%
plt.plot(area_loc1, price_loc1, 'go', label = 'Locality A')
plt.plot(area_loc2, price_loc2, 'b*', label = 'Locality B')
plt.title('Price vs Area Scatterplot')
plt.xlabel('Area of the house')
plt.ylabel('Price of the house')
plt.legend(loc='best') 
plt.show()

# %% [markdown]
# Now you must have known the importance of legends.
#
# But still the axis looks little dull. And what if you want to add the x ticks at every 50 units rather than 100. What if you want to tilt the labels to some degree or you want to make the labels little large.
#
# Let's see how to do that.
#
# ### Modify the Axis Ticks Positions and Labels
#
# There are 2 basic things you will probably ever need in matplotlib when it comes to manipulating axis ticks:
# 1. How to control the position and tick labels? (using plt.xticks())
# 2. How to control which axis’s ticks (top/bottom/left/right) should be displayed (using plt.tick_params())

# %%
# Add custom Ticks
plt.figure(figsize=(12,7), dpi=100) # to get a large figure

plt.plot(area_loc1, price_loc1, 'go', label = 'Locality A')
plt.plot(area_loc2, price_loc2, 'b*', label = 'Locality B')

plt.title('Price vs Area Scatterplot', fontsize=20)
plt.xlabel('Area of the house', fontsize=12)
plt.ylabel('Price of the house', fontsize=12)
plt.legend(loc='best')

# 1. Adjust x axis Ticks
plt.xticks(ticks=np.arange(0, 500, 50), fontsize=12, rotation=30, ha='center', va='top')  # 1 radian = 57.2985 degrees
plt.yticks(ticks=np.arange(0, 6000, 500))

# 2. Tick Parameters
plt.tick_params(axis='both', bottom=True, top=True, left=True, right=True, 
                direction='in', which='major', grid_color='blue')

plt.grid(linestyle='--', linewidth=0.5, alpha=0.55)
plt.show()

# %% [markdown]
# As you can see I have used some additional commands as well. Let's see what are these used for:
#
# - plt.figure(figsize=(12,7), dpi=100) - to specify the figure size and dpi of the plot
# - fontsize - to decide the font size of the texts
#
# - rotation - to rotate the ticks on the axis or some other text in the plot
# - plt.grid() - to enable the grids inside the plot,
# - linewidth - to decide the width of lines (grid lines in this example)
# - alpha - to decide on the plot fill opacity (from 0 to 1)
# - xticks - Values to use for x-axis ticks
# - tick_params - Change the appearance of ticks, tick labels, and gridlines.

# %% [markdown]
# Good so far. But what if you wish to draw two saperate plots rather than adding both in the same plot

# %%
# Set custom label text
plt.figure(figsize=(12,7), dpi=100) # to get a large figure

plt.plot(area_loc1, price_loc1, 'go', label = 'Locality A')
plt.plot(area_loc2, price_loc2, 'b*', label = 'Locality B')

plt.title('Price vs Area Scatterplot', fontsize=20)
plt.xlabel('Area of the house', fontsize=12)
plt.ylabel('Price of the house', fontsize=12)
plt.legend(loc='best')

# 1. Adjust x axis Ticks
plt.xticks(ticks=np.arange(0, 500, 50), labels=list('abcdefghij'), fontsize=12, rotation=30, ha='center', va='top') 
plt.yticks(ticks=np.arange(0, 6000, 500))

# 2. Tick Parameters
plt.tick_params(axis='both', bottom=True, top=True, left=True, right=True, 
                direction='in', which='major', grid_color='blue')

plt.grid(linestyle='--', linewidth=0.5, alpha=0.55)
plt.show()

# %% [markdown]
# ## Draw subplots
#
# Various plots in the matplotlib resides inside a figure object.

# %% [markdown]
# ![Plot](https://www.machinelearningplus.com/wp-content/uploads/2019/01/99_matplotlib_structure-1-640x646.png)

# %% [markdown]
# You already know how to create a new figure. i.e using `plt.figure`. You can create multiple subplots in a figure. Or I should say you can create a grid of subplots in a figure.
#
# There are 2 ways to create subplots:
# 1. You define the grid in the start itself. Example :  `fig, axes = plt.subplots(2, 3)`. It will create a grid of 6 suplots and these can be accessed using axes[i,j] i and j are the index of the subplots. The catch here is that it has created all the placeholders in the start itself. So if you don't use any of the subplots, there would be an empty box at that place.
# 2. You create the empty figure first and then keep on adding plots one by one. Example : `fig = plt.figure(figsize=(10,4), dpi=120)` It will create an empty figure. Till now it doesn't know what's coming to the plots.  `ax1 = fig.add_subplot(2, 2, 1)` this command will create the first plot in the figure of 2*2 plots
#
# Quite confusing right?
#
# Let's see it with an example:

# %%
area_loc1
# Out:
# [50, 90, 150, 200, 220, 250, 350, 500]

# %%
price_loc1
# Out:
# [400, 1000, 1300, 1900, 2200, 2400, 3570, 5100]

# %%
# Create Figure and Subplots
fig, axes = plt.subplots(2,2, figsize=(10,4), dpi=120)

# Plot
axes[0,0].plot(area_loc1, price_loc1, 'go')
axes[0,1].plot(area_loc2, price_loc2, 'b*')
axes[1,0].plot(area_loc2, price_loc2, 'b*')

# %% [markdown]
# Let's look at the 2nd way of creating subplots

# %%
fig = plt.figure(figsize=(10,4), dpi=120)
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# Plot
ax1.plot(area_loc1, price_loc1, 'go')
ax2.plot(area_loc2, price_loc2, 'b*')
ax3.plot(area_loc2, price_loc2, 'b*')

# %%
# Callingthe plots with plt instead.
fig = plt.figure(figsize=(10,4), dpi=120)

fig.add_subplot(2, 2, 1)
plt.plot(area_loc1, price_loc1, 'go')

ax2 = fig.add_subplot(2, 2, 2)
plt.plot(area_loc2, price_loc2, 'b*')

ax3 = fig.add_subplot(2, 2, 3)
plt.plot(area_loc2, price_loc2, 'b*')

# %% [markdown]
# I hope it's clear now.
#
# Other commands like y_label, title etc also needs a slight modification now.
#
# The ax1, ax2 and ax3 objects, like plt, has equivalent set_title, set_xlabel and set_ylabel functions. Infact, the plt.title() actually calls the current axes set_title() to do the job.
#
# - plt.xlabel() - ax.set_xlabel()
# - plt.ylabel() - ax.set_ylabel()
# - plt.title() - ax.set_title()
#
# Now let's jump to our previous example of price vs area in locality

# %% [markdown]
# Suppose, You want to draw our two sets of points (locality A and locality B) in two separate plots side-by-side instead of the same plot. How would you do that?
#
# You can do that by creating two separate subplots, aka, axes using `plt.subplots(1, 2)`. This creates and returns two objects:
#
# 1. Figure
# 2. Axes
#
#
# Previously, I called `plt.plot()` to draw the points. Since there was only one axes by default, it drew the points on that axes itself.
#
# But now, since you want the points drawn on different subplots (axes), you have to call the plot function in the respective axes (ax1 and ax2 in below code) instead of plt.
#
# Notice in below code, I call `ax1.plot()` and `ax2.plot()` instead of calling `plt.plot()` twice.

# %%
# Create Figure and Subplots
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,4), sharey=False, dpi=120)

# Plot
ax1.plot(area_loc1, price_loc1, 'go')
ax2.plot(area_loc2, price_loc2, 'b*')

# Title, X and Y labels, X and Y Lim
ax1.set_title('Price vs Area Scatterplot Locality A'); ax2.set_title('Price vs Area Scatterplot Locality B')
ax1.set_xlabel('Area of the house');  ax2.set_xlabel('Area of the house')  # x label
ax1.set_ylabel('Price of the house');  ax2.set_ylabel('Price of the house')  # y label
ax1.set_ylim(2000, 4000)
ax2.set_ylim(0, 6000)

fig.suptitle("Overall Title")
fig.tight_layout()

plt.show()

# %% [markdown]
# Setting sharey=True in plt.subplots() shares the Y axis between the two subplots.
#
# And dpi=120 increased the number of dots per inch of the plot to make it look more sharp and clear. You will notice a distinct improvement in clarity on increasing the dpi especially in jupyter notebooks.
#
# What if you wish to add some text and annotations in the plot? Any idea how to do that?

# %% [markdown]
# ## Add annotations to the plot
#
# You can add texts and annotations to the plot using `plt.annotate` function

# %%
# Create Figure and add Annotations
plt.figure(figsize=(12,7))
plt.plot(area_loc1, price_loc1, 'go', label = 'Locality A')
plt.plot(area_loc2, price_loc2, 'b*', label = 'Locality B')
plt.title('Price vs Area Scatterplot', fontsize=20)
plt.xlabel('Area of the house', fontsize=12)
plt.ylabel('Price of the house', fontsize=12)
plt.legend(loc='best')
# 
# Annotation
plt.annotate('Price B < Price A', xy =(150, 1300 + 100),
                xytext =(150, 1300 + 500), 
                arrowprops =dict(facecolor='black', headwidth=5, width=2, headlength=4),
                horizontalalignment='left', verticalalignment='top')


plt.show()

# %% [markdown]
# __Annotate the points__

# %%
# Create Figure and add Annotations
plt.figure(figsize=(12,7))
plt.plot(area_loc1, price_loc1, 'go', label = 'Locality A')
plt.plot(area_loc2, price_loc2, 'b*', label = 'Locality B')
plt.title('Price vs Area Scatterplot', fontsize=20)
plt.xlabel('Area of the house', fontsize=12)
plt.ylabel('Price of the house', fontsize=12)
plt.legend(loc='best')

# Annotate all points
for i, val in enumerate(price_loc2):
    plt.annotate(str(val), xy =(area_loc1[i], val),
                xytext =(area_loc1[i], val + 150), 
                horizontalalignment='center', 
                verticalalignment='center')

plt.show()

# %% [markdown]
# I hope everything is clear by now.
#
# Now let's look at how to save the plot
#
# ### Save the plot
#
# Use `plt.savefig` to save the figure/plot in the system.
#
# You have lot of options while saving the plot. You can either save it as .pdf, .jpeg, .png or .svg etc. All you have to do is change the extension in the end

# %%
# Save the figure
plt.savefig('price_analysis.png')

# %% [markdown]
# `savefig` needs to be called before `plt.show()`

# %%
# Create Figure and add Annotations
plt.figure(figsize=(12,7), dpi=100) # to get a large figure
plt.plot(area_loc1, price_loc1, 'go', label = 'Locality A')
plt.plot(area_loc2, price_loc2, 'b*', label = 'Locality B')
plt.title('Price vs Area Scatterplot', fontsize=20)
plt.xlabel('Area of the house', fontsize=12)
plt.ylabel('Price of the house', fontsize=12)
plt.legend(loc='best')

# Annotate all points
for i, val in enumerate(price_loc2):
    plt.annotate(str(val), xy =(area_loc1[i], val),
                xytext =(area_loc1[i], val + 150), 
                horizontalalignment='center', 
                verticalalignment='center')
    
plt.savefig('price_analysis.png')   # dpi, pdf supported   
plt.show()

# %% [markdown]
# The plot got saved in the file price_analysis.png.
#
# You can use various other parameters to enhance the image. Use dpi to enhance the dots per inch resolution.

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>2. Plotting Correlation: Relationship between two numerical variables</h2>
# </div>

# %% [markdown]
# If you wish to understand the relationship between two or more numerical variables, you can use the following plots:
#
# - Scatterplot and Regression Plot (lines of best fit)
# - Correlation matrix with Heatmap

# %% [markdown]
# ## 2.1. Scatter Plot
#
# Scatteplot is a classic and fundamental plot used to study the relationship between two variables.
#
# __When to use scatter plot?__
#
# Scatter plots are used to:
# - Analyze the relationship between two numeric variables
# - Analyze the relationship between two numeric variables in presence of a categorical variable
#
# __Various types__
# - Scatter Plot
# - Coloured Scatter Plot for various categories
# - Regression Plot
#
# __Use Cases__
# - Check the population spread across area
# - Analyze the relationship between sales and advertising
# - Analyze the effect of COVID-19 positivity rate and vaccination rate
#
# __Scatter Plot__
#
# Use `plt.scatter()` to draw a scatter plot
#
# Task:
# - Check the population spread across area in midwest area
#
# or in other words
#
# - Find the relation between population and area

# %%
import pandas as pd
import numpy as np
import warnings

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# %matplotlib inline

warnings.filterwarnings("ignore")

# %%
# Import dataset 
midwest = pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/midwest_filter.csv")
midwest.head()
# Out:
#    PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0  561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1  562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2  563       BOND    IL  0.022     14991   681.409091     14477       429
# 3  564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4  565      BROWN    IL  0.018      5836   324.222222      5264       547
#
#    popamerindian  popasian  ...  percprof  poppovertyknown  percpovertyknown  \
# 0             98       249  ...  4.355859            63628         96.274777
# 1             19        48  ...  2.870315            10529         99.087145
# 2             35        16  ...  4.488572            14235         94.956974
# 3             46       150  ...  4.197800            30337         98.477569
# 4             14         5  ...  3.367680             4815         82.505140
#
#    percbelowpoverty  percchildbelowpovert  percadultpoverty  \
# 0         13.151443             18.011717         11.009776
# 1         32.244278             45.826514         27.385647
# 2         12.068844             14.036061         10.852090
# 3          7.209019             11.179536          5.536013
# 4         13.520249             13.022889         11.143211
#
#    percelderlypoverty  inmetro  category    dot_size
# 0           12.443812        0       AAR  250.944411
# 1           25.228976        0       LHR  185.781260
# 2           12.697410        0       AAR  175.905385
# 3            6.217047        1       ALU  319.823487
# 4           19.200000        0       AAR  130.442161
#
# [5 rows x 29 columns]

# %% [markdown]
# Let's draw the plot

# %%
# Plot Bars
plt.rcParams['figure.dpi'] = 100
midwest.plot(x='area', y='poptotal', kind='scatter', figsize=(12,7))

# Decorations
plt.gca().set(xlim=(0.0, 0.1), ylim=(0, 90000),
              xlabel='Area', ylabel='Population')

plt.xticks(fontsize=7); plt.yticks(fontsize=6)
plt.title("Scatterplot of Midwest Area vs Population", fontsize=12)   
plt.show();

# %% [markdown]
# __Coloured Scatter Plot for various categories__
#
# Use `plt.scatter()` inside a for loop iterating over all categories and use `c =` argument to specify colour for each category
#
# Task:
# - Check the population spread across area in midwest area, colour the dots with category
#
# or in other words
#
# - Find the relation between population and area and colour the dots with category

# %%
# Create as many colors as there are unique midwest['category']
categories = np.unique(midwest['category'])
colors = [plt.cm.tab10(i/float(len(categories)-1)) for i in range(len(categories))]

# %%
colors
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765, 1.0),
#  (0.12156862745098039, 0.4666666666666667, 0.7058823529411765, 1.0),
#  (1.0, 0.4980392156862745, 0.054901960784313725, 1.0),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313, 1.0),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392, 1.0),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392, 1.0),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353, 1.0),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354, 1.0),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902, 1.0),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902, 1.0),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745, 1.0),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333, 1.0),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529, 1.0),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529, 1.0)]

# %% [markdown]
# Let's draw the plot

# %%
# Draw Plot for Each Category
fig, axes = plt.subplots(1,1, figsize=(10,7), dpi=120)

for i, category in enumerate(categories):
    midwest.loc[midwest.category==category, :].plot(x='area', 
            y='poptotal', 
            kind='scatter', 
            ax=axes,
            s=20, 
            color=colors[i], 
            label=str(category))
    
    
# Decorations based on axes
plt.gca().set(xlim=(0.0, 0.1), ylim=(0, 90000),
              xlabel='Area', ylabel='Population')

plt.xticks(fontsize=8); plt.yticks(fontsize=8)
plt.title("Scatterplot of Midwest Area vs Population", fontsize=14)
plt.legend(fontsize=8)    
plt.show()   

# # Alternate Syntax based on plt
# plt.title("Scatterplot of Midwest Area vs Population", fontsize=22)
# plt.xlabel("Area", fontsize = 12)
# plt.ylabel("Population", fontsize = 12)
# plt.xlim(0, 45)
# plt.ylim(0, 90000)
# plt.show()

# %% [markdown]
# ### Reg Plot
#
# Use `sns.regplot()` to draw a scatter plot with loess line
#
# Task:
# - Check the population spread across area in midwest area, draw a loess line as well
#
# or in other words
#
# - Find the relation between population and area, draw a loess line as well

# %%
# Plot Bars
plt.figure(figsize=(16,10), dpi= 100)
sns.regplot(midwest['area'], midwest['poptotal'])

# Decorations
plt.gca().set(xlim=(0.0, 0.1), ylim=(0, 90000),
              xlabel='Area', ylabel='Population')

plt.xticks(fontsize=8); plt.yticks(fontsize=8)
plt.title("Scatterplot of Midwest Area vs Population", fontsize=14)   
plt.show()

# %% [markdown]
# __Multiple Lines of Best Fit in same Plot__
#
# Use `sns.lmplot` instead and set the `hue` to the categorical variable.

# %%
# Multiple Lines of best fit in same plot
plt.figure(figsize=(12,7), dpi= 100)
sns.lmplot(data=midwest, x='area', y='poptotal', hue='inmetro', ci=None)

# Decorations
plt.gca().set(xlim=(0.0, 0.1), ylim=(0, 90000),
              xlabel='Area', ylabel='Population')

plt.xticks(fontsize=8); plt.yticks(fontsize=8)
plt.title("Scatterplot of Midwest Area vs Population", fontsize=14)   
plt.show();

# %% [markdown]
# Challenge:
# - Check the population spread across area in midwest area using regplot with seperate loess lines for ever category

# %% [markdown]
# ## 2.2. Correlation Matrix with Heatmap
#
# __Correlation matrix__
# Correlation matrix is a table used to show the correlation coefficients between various variables. Rows and Columns contains all numerical columns. Each cell of the correlation matrix shows the correlation between two variables (row vs column)
#
# __Heatmap__
# Heat map is used to show the variation in magnitude of values in a variable as colors. These colors vary by hue or intensity, you can set the colours as per your convenience.
#
# We are going to use it with correlation matrix to show the correlation visually as you will get obvious visual cues about how the values are clustered or varies.
#
# __When to use correlation matrix?__
#
# Correlation matrix is used to:
# - Analyze the correlation/relationship between two or more numeric variables
#
# __Use Cases__
# - Check multicollinearity between the x variables in a regression model
# - Analyze the relationship between sales and advertising
# - Analyze the effect of vaccination rate on COVID-19 positivity rate
#
# __Correlation Matrix__
#
# Use `.corr` to compute a correlation matrix
#
# Task:
# - Compute the correlation matrix of all the numeric variables in the data
#
# or in other words
#
# - Find the relation between all the numeric variables in the data

# %%
midwest.corr()
# Out:
#                            PID      area  poptotal  popdensity  popwhite  \
# PID                   1.000000  0.397870  0.133294   -0.050739  0.137512
# area                  0.397870  1.000000  0.126524   -0.351645  0.123563
# poptotal              0.133294  0.126524  1.000000    0.751347  0.998397
# popdensity           -0.050739 -0.351645  0.751347    1.000000  0.748286
# popwhite              0.137512  0.123563  0.998397    0.748286  1.000000
# popblack             -0.083413 -0.037245  0.499686    0.480880  0.455958
# popamerindian         0.229635  0.404368  0.039698   -0.103978  0.015806
# popasian              0.035261  0.097091  0.588614    0.388431  0.570111
# popother              0.005521  0.003116  0.469500    0.343886  0.454590
# percwhite            -0.070447 -0.046703  0.013972    0.012110  0.048354
# percblack            -0.132705 -0.111052  0.095578    0.137790  0.061791
# percamerindan         0.161997  0.119572 -0.131730   -0.137776 -0.148670
# percasian             0.010984  0.089345  0.419581    0.254901  0.401127
# percother            -0.017605 -0.043861  0.275893    0.219467  0.263677
# popadults             0.133403  0.132896  0.994455    0.752281  0.993771
# perchsd               0.089440  0.157593  0.413884    0.277302  0.419669
# percollege            0.096019  0.182910  0.436649    0.304053  0.432850
# percprof             -0.127584 -0.012573  0.455560    0.417714  0.447675
# poppovertyknown       0.136902  0.118862  0.998046    0.758582  0.998022
# percpovertyknown      0.052512 -0.121478 -0.203449   -0.046622 -0.182085
# percbelowpoverty      0.051412  0.086992 -0.266655   -0.295274 -0.288213
# percchildbelowpovert  0.066173  0.077046 -0.282462   -0.283781 -0.301426
# percadultpoverty      0.053580  0.113933 -0.201092   -0.261792 -0.223714
# percelderlypoverty   -0.065851 -0.002447 -0.431445   -0.375685 -0.442678
# inmetro              -0.066014 -0.166596  0.288171    0.382586  0.295374
# dot_size             -0.050739 -0.351645  0.751347    1.000000  0.748286
#
#                       popblack  popamerindian  popasian  popother  percwhite  \
# PID                  -0.083413       0.229635  0.035261  0.005521  -0.070447
# area                 -0.037245       0.404368  0.097091  0.003116  -0.046703
# poptotal              0.499686       0.039698  0.588614  0.469500   0.013972
# popdensity            0.480880      -0.103978  0.388431  0.343886   0.012110
# popwhite              0.455958       0.015806  0.570111  0.454590   0.048354
# popblack              1.000000       0.061915  0.466115  0.270682  -0.338662
# popamerindian         0.061915       1.000000  0.041773  0.003766  -0.618584
# popasian              0.466115       0.041773  1.000000  0.298920  -0.102050
# popother              0.270682       0.003766  0.298920  1.000000  -0.090061
# percwhite            -0.338662      -0.618584 -0.102050 -0.090061   1.000000
# percblack             0.657415       0.006583  0.159923  0.065562  -0.500954
# percamerindan        -0.042671       0.711747 -0.056196 -0.052645  -0.840686
# percasian             0.388366       0.018019  0.934645  0.208863  -0.089493
# percother             0.139556      -0.020087  0.160545  0.913006  -0.081231
# popadults             0.496775       0.034004  0.532224  0.457326   0.022728
# perchsd               0.019659       0.068412  0.346576  0.259402   0.133595
# percollege            0.166312       0.097506  0.610232  0.197721   0.030426
# percprof              0.264963       0.038114  0.727597  0.169332   0.023370
# poppovertyknown       0.477912       0.031744  0.559059  0.470173   0.025260
# percpovertyknown     -0.392592      -0.127577 -0.428960 -0.063489   0.181908
# percbelowpoverty      0.140014       0.275842  0.047958 -0.188992  -0.500124
# percchildbelowpovert  0.116373       0.267774 -0.093228 -0.197128  -0.481661
# percadultpoverty      0.165711       0.281562  0.180186 -0.148788  -0.470285
# percelderlypoverty    0.015146       0.027234 -0.215029 -0.304875  -0.220367
# inmetro               0.044894      -0.061539  0.112623  0.122529   0.057831
# dot_size              0.480880      -0.103978  0.388431  0.343886   0.012110
#
#                       ...  percollege  percprof  poppovertyknown  \
# PID                   ...    0.096019 -0.127584         0.136902
# area                  ...    0.182910 -0.012573         0.118862
# poptotal              ...    0.436649  0.455560         0.998046
# popdensity            ...    0.304053  0.417714         0.758582
# popwhite              ...    0.432850  0.447675         0.998022
# popblack              ...    0.166312  0.264963         0.477912
# popamerindian         ...    0.097506  0.038114         0.031744
# popasian              ...    0.610232  0.727597         0.559059
# popother              ...    0.197721  0.169332         0.470173
# percwhite             ...    0.030426  0.023370         0.025260
# percblack             ...   -0.012765  0.038474         0.080278
# percamerindan         ...   -0.079996 -0.105176        -0.133738
# percasian             ...    0.593593  0.704472         0.386729
# percother             ...    0.125069  0.086129         0.277904
# popadults             ...    0.408591  0.407105         0.996121
# perchsd               ...    0.724251  0.559612         0.412229
# percollege            ...    1.000000  0.823491         0.421720
# percprof              ...    0.823491  1.000000         0.430502
# poppovertyknown       ...    0.421720  0.430502         1.000000
# percpovertyknown      ...   -0.262385 -0.396381        -0.149641
# percbelowpoverty      ...   -0.252541 -0.146069        -0.283668
# percchildbelowpovert  ...   -0.344354 -0.281567        -0.289831
# percadultpoverty      ...   -0.130507 -0.007549        -0.224741
# percelderlypoverty    ...   -0.421267 -0.323060        -0.437305
# inmetro               ...    0.210741  0.223042         0.295986
# dot_size              ...    0.304053  0.417714         0.758582
#
#                       percpovertyknown  percbelowpoverty  \
# PID                           0.052512          0.051412
# area                         -0.121478          0.086992
# poptotal                     -0.203449         -0.266655
# popdensity                   -0.046622         -0.295274
# popwhite                     -0.182085         -0.288213
# popblack                     -0.392592          0.140014
# popamerindian                -0.127577          0.275842
# popasian                     -0.428960          0.047958
# popother                     -0.063489         -0.188992
# percwhite                     0.181908         -0.500124
# percblack                    -0.306371          0.318748
# percamerindan                 0.006072          0.402749
# percasian                    -0.476280          0.087909
# percother                    -0.021063         -0.186242
# popadults                    -0.162067         -0.288430
# perchsd                      -0.082046         -0.592075
# percollege                   -0.262385         -0.252541
# percprof                     -0.396381         -0.146069
# poppovertyknown              -0.149641         -0.283668
# percpovertyknown              1.000000         -0.153158
# percbelowpoverty             -0.153158          1.000000
# percchildbelowpovert         -0.024713          0.959402
# percadultpoverty             -0.247255          0.977352
# percelderlypoverty           -0.015443          0.757739
# inmetro                       0.051741         -0.309172
# dot_size                     -0.046622         -0.295274
#
#                       percchildbelowpovert  percadultpoverty  \
# PID                               0.066173          0.053580
# area                              0.077046          0.113933
# poptotal                         -0.282462         -0.201092
# popdensity                       -0.283781         -0.261792
# popwhite                         -0.301426         -0.223714
# popblack                          0.116373          0.165711
# popamerindian                     0.267774          0.281562
# popasian                         -0.093228          0.180186
# popother                         -0.197128         -0.148788
# percwhite                        -0.481661         -0.470285
# percblack                         0.311780          0.291191
# percamerindan                     0.394496          0.372711
# percasian                        -0.066418          0.227674
# percother                        -0.177215         -0.159563
# popadults                        -0.284867         -0.233703
# perchsd                          -0.622682         -0.491593
# percollege                       -0.344354         -0.130507
# percprof                         -0.281567         -0.007549
# poppovertyknown                  -0.289831         -0.224741
# percpovertyknown                 -0.024713         -0.247255
# percbelowpoverty                  0.959402          0.977352
# percchildbelowpovert              1.000000          0.901714
# percadultpoverty                  0.901714          1.000000
# percelderlypoverty                0.697773          0.667645
# inmetro                          -0.298250         -0.286683
# dot_size                         -0.283781         -0.261792
#
#                       percelderlypoverty   inmetro  dot_size
# PID                            -0.065851 -0.066014 -0.050739
# area                           -0.002447 -0.166596 -0.351645
# poptotal                       -0.431445  0.288171  0.751347
# popdensity                     -0.375685  0.382586  1.000000
# popwhite                       -0.442678  0.295374  0.748286
# popblack                        0.015146  0.044894  0.480880
# popamerindian                   0.027234 -0.061539 -0.103978
# popasian                       -0.215029  0.112623  0.388431
# popother                       -0.304875  0.122529  0.343886
# percwhite                      -0.220367  0.057831  0.012110
# percblack                       0.320075 -0.036275  0.137790
# percamerindan                   0.106431 -0.058956 -0.137776
# percasian                      -0.164167  0.046167  0.254901
# percother                      -0.286294  0.095328  0.219467
# popadults                      -0.435647  0.285597  0.752281
# perchsd                        -0.710052  0.271583  0.277302
# percollege                     -0.421267  0.210741  0.304053
# percprof                       -0.323060  0.223042  0.417714
# poppovertyknown                -0.437305  0.295986  0.758582
# percpovertyknown               -0.015443  0.051741 -0.046622
# percbelowpoverty                0.757739 -0.309172 -0.295274
# percchildbelowpovert            0.697773 -0.298250 -0.283781
# percadultpoverty                0.667645 -0.286683 -0.261792
# percelderlypoverty              1.000000 -0.319212 -0.375685
# inmetro                        -0.319212  1.000000  0.382586
# dot_size                       -0.375685  0.382586  1.000000
#
# [26 rows x 26 columns]

# %% [markdown]
# __Heatmap__
#
# Use `seaborn.heatmap` to draw a heatmap
#
# Task:
# - Draw the heatmap on the correlation matrix of all the numeric variables in the data
#
# or in other words
#
# - Visually show the relation between all the numeric variables in the data
#
# __Note:__ Since the correlation matrix is very big, I am drawing the heatmap only on 15 features so that it can be clearly analyzed

# %%
import seaborn as sns

# Draw Hearmmap on correlation matrix
plt.figure(figsize=(12,7), dpi=100) # to get a large figure
sns.heatmap(midwest.iloc[:15,:15].corr(), annot=True,cmap='RdYlGn',center=0)
plt.title('Correlation Matrix', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>3. Plotting Distribution of Variables</h2>
# </div>

# %% [markdown]
# If you wish to understand the distribution of various variables, you can use the following plots:
#
# - Histogram and Density Plot
# - Bar Plot and it's variation
# - Box Plot and Violin Plot

# %% [markdown]
# ## 3.1. Histogramm
#
# ### Histogram
#
# Histogram is a type of bar plot which is used to represent the distribution of variable.
#
# You have frequency on the y axis and values on the x axis. It displays the spread of continuous variable
#
# You can specify the number of bars/groups on the y axis. These are called bins.
#
# ### Density Plot
#
# Density plot is a smoothed version of the histograms and is used to represent the distribution of variable.
#
# __When to use histogram and density plot?__
#
# These plots are used to:
# - Visualize the distribution of variable
#
# __Use Cases__
# - Analyze the distribution of sales over the year
# - Decide if a specific ML algo can be used to model the data. Few ML algorithms assume the variables to be normally distributed.
#
#
# __Histogram__
#
# Use `plt.hist` to plot histogram. Specify the number of bins using `bins = `
#
# Task:
# - Check the distribution of displacement variable in mpg dataset

# %%
import pandas as pd

df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
df_raw.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
# Plot Bars
df_raw['displ'].plot(by='displ', bins = 15, figsize=(16,10), kind="hist")

# Decoration
plt.title("Histogram of Displacement", fontsize=22)
plt.xlabel("displ", fontsize = 12)
plt.ylabel("Frequency", fontsize = 12)
plt.ylim(0, 45)

plt.show()

# %% [markdown]
# __Density Plot with Seaborn__
#
# Use `sns.distplot` to plot density plot. Use `hist = False` if you wish to draw only the density plot else use `hist = True` for density plot with histogram

# %%
import seaborn as sns

# %%
# Plot Bars
plt.figure(figsize=(16,10), dpi= 80)
sns.distplot(df_raw['displ'], bins = 15, hist = True)

# Decoration
plt.title("Number of Vehicles by Manaufacturers", fontsize=22)
plt.xlabel('Manufacturer', fontsize=12)
plt.ylabel('# Vehicles', fontsize=12)
plt.show()

# %% [markdown]
# #### Mini Challenge:
#
# Draw a histogram to check the distribution of displacement variable (`displ`) grouped by `drv` column in mpg dataset.
#
# ```python
# import pandas as pd
# df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
# df_raw.head()
# ```

# %% [markdown]
# ## 3.2. Bar Chart and it's variations
#
# Bar chart is a classic way of visualizing items based on counts or any given metric. Or it can be used to view the composition
#
# It represents categorical data with the category on the x axis and values on the y axis (height of the bars) and vice-versa (in case of horizontal bar plot). The bars can be plotted vertically or horizontally. A bar graph shows comparisons among discrete categories.
#
# __When to use bar plot?__
#
# Bar plots are used to:
# - Analyze the composition
# - Represent the categorical data based on the counts or values
# - Compare the discrete categories
#
# __Various types of bar plot__
# - Vertical
# - Horizontal
# - Multiple Bars by category
# - Stacked
#
# __Use Cases__
# - Compare various manufacturing companies based on the number of unique vehicles they manufacture
# - Compare the sales of various products
#
# __Vertical Bar Plot__
#
# In case of vertical bar plots, the vertical axis represents the count/values and the horizontal axis represents the categories
#
# Task:
# - To compare the number of unique vehicles manufactured by various automobile companies

# %%
import pandas as pd

# %%
# Import Data
df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
df_raw.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
# Let's get the count of vehicles manufactured by various companies

# %%
# Prepare Data
df = df_raw.groupby('manufacturer').size().reset_index(name='counts')
df.head()
# Out:
#   manufacturer  counts
# 0         audi      18
# 1    chevrolet      19
# 2        dodge      37
# 3         ford      25
# 4        honda       9

# %% [markdown]
# Now let's draw the bar plot

# %%
# Plot Bars
plt.figure(figsize=(16,10), dpi= 80)
plt.bar(df['manufacturer'], df['counts'], width=.5)

# Add the count on top of bar plot
for i, val in enumerate(df['counts'].values):
    plt.text(i, val, float(val), 
             horizontalalignment='center', verticalalignment='bottom', 
             fontdict={'fontweight':500, 'size':12})

# Decoration
plt.gca().set_xticklabels(df['manufacturer'], rotation=60, horizontalalignment= 'right')
plt.title("Number of Vehicles by Manaufacturers", fontsize=22)
plt.xlabel('Manufacturer', fontsize=12)
plt.ylabel('# Vehicles', fontsize=12)
plt.ylim(0, 45)
plt.show()

# %% [markdown]
# __Horizontal Bar Chart__
#
# It is similar to vertical bar chart. But it's represented horizontally and ordered by the x axis (in most of the cases)
#
# In case of vertical bar plots, the vertical axis represents the count/values and the horizontal axis represents the categories
#
# All you have to do is use `plt.barh` insted of `plt.bar`
#
# Task:
# - To compare the number of unique vehicles manufactured by various automobile companies
# - Sort the automobile companies by the number of unique vehicles

# %%
# Prepare Data
df = df_raw.groupby('manufacturer').size().reset_index(name='counts')
df = df.sort_values('counts', ascending=True)
df.head()
# Out:
#    manufacturer  counts
# 8       lincoln       3
# 7    land rover       4
# 9       mercury       4
# 11      pontiac       5
# 6          jeep       8

# %%
# Plot Bars
plt.figure(figsize=(16,10), dpi= 80)
plt.barh(df['manufacturer'], df['counts'])

# Add the count on top of bar plot
for val, i in enumerate(df['counts'].sort_index(ascending=False).sort_values(ascending=True).values):
    plt.text(i, val, float(i), 
             horizontalalignment='left', verticalalignment='center', 
             fontdict={'fontweight':500, 'size':12})

# Decoration
plt.gca().set_yticklabels(df['manufacturer'], rotation=60, horizontalalignment= 'right')
plt.title("Number of Vehicles by Manaufacturers", fontsize=22)
plt.xlabel('Manufacturer', fontsize=12)
plt.ylabel('# Vehicles', fontsize=12)
plt.xlim(0, 45)
plt.show()

# %% [markdown]
# __Multiple Bars by Category - Grouped Bar Plot__
#
# Grouped bar chart or multi-series bar chart or clustered bar chart is an extention to the bar chart. It plots the values for the levels of two categorical variables instead of one.
#
# The plotting function is the same, all you have to do is transform the data to required format
#
# Task:
# - To compare the number of unique vehicles grouped by the type of drive (4 wheel drive, frond wheel drive and back wheel drive) manufactured by various automobile companies

# %%
# Tranform the data to get drive flag as column and automobile company as the row number
df_raw.groupby('manufacturer').drv.value_counts().unstack()
# Out:
# drv              4     f     r
# manufacturer
# audi          11.0   7.0   NaN
# chevrolet      4.0   5.0  10.0
# dodge         26.0  11.0   NaN
# ford          13.0   NaN  12.0
# honda          NaN   9.0   NaN
# hyundai        NaN  14.0   NaN
# jeep           8.0   NaN   NaN
# land rover     4.0   NaN   NaN
# lincoln        NaN   NaN   3.0
# mercury        4.0   NaN   NaN
# nissan         4.0   9.0   NaN
# pontiac        NaN   5.0   NaN
# subaru        14.0   NaN   NaN
# toyota        15.0  19.0   NaN
# volkswagen     NaN  27.0   NaN

# %%
# Draw plot
df_unstack = df_raw.groupby('manufacturer').drv.value_counts().unstack()
df_unstack.plot.bar(figsize=(16,10), title="Number of Vehicles by Manaufacturers",
                   xlabel='Manufacturer',
                   ylabel='# Vehicles',
                   ylim=(0, 35))
# Out:
# <AxesSubplot:title={'center':'Number of Vehicles by Manaufacturers'}, xlabel='Manufacturer', ylabel='# Vehicles'>

# %% [markdown]
# __Stacked Bar Chart__
#
# Stacked bar chart is similar to grouped bar chart. Here rather than having seperate bars for level 2 category, the bar is broken into smaller bars representing level 2 categories.
#
# All you have to do is put `stacked = True` while plotting.
#
# Task:
# - To compare the number of unique vehicles grouped by the type of drive (4 wheel drive, frond wheel drive and back wheel drive) manufactured by various automobile companies

# %%
# Stacked Bar chart
df_stacked = df_raw.groupby('manufacturer').drv.value_counts().unstack()
df_stacked.plot.bar(figsize=(16,10), stacked = True)

# You can add the element properties individually as well
plt.title("Number of Vehicles by Manaufacturers", fontsize=22)
plt.xlabel('Manufacturer', fontsize=12)
plt.ylabel('# Vehicles', fontsize=12)
plt.ylim(0, 40)
plt.show()

# %% [markdown]
# ## 3.3. Boxplot and Violin Plot
#
# ### Boxplot
#
# Boxplot is used to represent the distribution of variable with help of the quartiles. You can clearly see the outliers as well
#
# It shows 1st quartile, median, 3rd quartile, lower and upper whiskers
#
# ### Violin Plot
#
# Viloin plot is similar to box plot. It represents a kernel density estimation of the underlying distribution.
#
# __When to use boxplot and violin plot?__
#
# These plots are used to:
# - Visualize the distribution of variable
# - Check the outliers
#
# __Use Cases__
# - Analyze the distribution of sales over the year
# - Decide if a specific ML algo can be used to model the data. Few ML algorithms assume the variables to be normally distributed.
#
#
# __Boxplot__
#
# Use `sns.boxplot` to plot boxplot.
#
# Task:
# - Check the distribution of displacement variable in mpg dataset

# %%
import pandas as pd

df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
df_raw.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
# Plot Boxplot
plt.figure(figsize=(16,10), dpi= 80)
sns.boxplot(df_raw['displ'])

# Decoration
plt.title("Boxplot of Displacement", fontsize=22)
plt.xlabel("displ", fontsize = 12)

plt.show()

# %% [markdown]
# __Violin Plot__
#
# Use `sns.violinplot` to plot violin plot.

# %%
# Violin Plot
plt.figure(figsize=(16,10), dpi= 80)
sns.violinplot(df_raw['displ'])

# Decoration
plt.title("Violin Plot of Displacement", fontsize=22)
plt.xlabel("displ", fontsize = 12)
plt.ylabel("Frequency", fontsize = 12)

plt.show()

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>4. Plotting Relationship between numerical vs categorical variable</h2>
# </div>

# %% [markdown]
# If you wish to understand the relationship between numerical and categorical variables, you can use the following plots:
#
# - Multiple Box Plots
# - Bubble Plots
# - Pair Plots
# - Trellis Chart or Facets

# %% [markdown]
# ## 4.1. Multiple Box Plots
#
# A single boxplot is used to represent the distribution of variable and outliers with help of the quartiles. If you wish to see the distribution of variable based on another categorical variable, you  can use multiple box plots
#
#
# __When to use multiple boxplot ?__
#
# These plots are used to:
# - Understand the relation between numerical and categorical variables
#
# __Use Cases__
# - Analyze the distribution of sales for every month
# - Analyze the distribution of price of car for every body-type
#
# __Multiple Box Plot__
#
# Use `sns.boxplot` to plot boxplot.
#
# Task:
# - Check the distribution of displacement variable for every class of cars in mpg dataset

# %%
import pandas as pd

df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
df_raw.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
# Plot Boxplot
plt.figure(figsize=(16,10), dpi= 80)
sns.boxplot(x='class', y='displ', data=df_raw, notch=False)

# Decoration
plt.title("Displacement vs Class", fontsize=22)
plt.xlabel("Class", fontsize = 12)
plt.ylabel("Displ", fontsize = 12)

plt.show()

# %% [markdown]
# ## 4.2. Bubble Plot
#
# A bubble plot is used to represent three dimensions of data in  2D plot. Be it 2 numerical 1 categorical or 3 numerical. It's an extension of scatter plot where the size of scatter points is different as per the 3rd variable
#
#
# __When to use bubble plot ?__
#
# These plots are used to:
# - Understand the relation between numerical and categorical variables
# - Understand the relation between three numerical variables
#
# __Use Cases__
# - Analyze the relationship of sales and profit for every month
# - Analyze the relationship of sales and profit and price of item
#
#
# Task:
# - Check the relationship between displacement and hwy variable for every class of cars in mpg dataset

# %%
df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
df_raw['class_encoded'] = df_raw['class'].astype('category').cat.codes
df_raw['class_encoded'] = df_raw['class_encoded']* 10
df_raw.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    class_encoded
# 0             10
# 1             10
# 2             10
# 3             10
# 4             10

# %%
# As many colors as there are unique midwest['category']
categories = np.unique(df_raw['class'])
colors = [plt.cm.tab10(i/float(len(categories)-1)) for i in range(len(categories))]

# Draw Scatterplot with unique color and size for each category
fig = plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k')    

for i, category in enumerate(categories):
    plt.scatter('displ', 'hwy', data=df_raw.loc[df_raw['class'] == category, :] ,c=colors[i], label=str(category), edgecolors='black', linewidths=.5, s='class_encoded')


# Decorations
plt.gca().set(xlabel='Displ', ylabel='Highway')

plt.xticks(fontsize=12); plt.yticks(fontsize=12)
plt.title("Bubble Plot", fontsize=22)
plt.legend(fontsize=12)    
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ## 4.3. Pair Plot
#
# Pair plot is used to plot pairwise relationships in a dataset.
#
# By default, this function will create a grid of Axes such that each numeric variable in data will by shared across the y-axes across a single row and the x-axes across a single column. The diagonal plots are treated differently: a univariate distribution plot is drawn to show the marginal distribution of the data in each column.
#
# It is also possible to show a subset of variables or plot different variables on the rows and columns.
#
# __When to use pair plot?__
#
# Pair plots are used to:
# - Do the univariate and bivariate analysis with 1 line of code
#
# Use `sns.pairplot()` to draw the pair plot
#
# Task:
# - Do the univariate and multivariate analysis of mpg dataset

# %%
# Import Data
import pandas as pd
df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
df_raw.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
# Let's draw the plot

# %%
# Plot 
plt.figure(figsize=(16,10), dpi= 80)
sns.pairplot(df_raw, diag_kind='kde', plot_kws={'alpha': 0.2}, )   
plt.show()

# %% [markdown]
# __View by category__

# %%
# Plot Bars
plt.figure(figsize=(16,10), dpi= 80)
sns.pairplot(df_raw, diag_kind='kde', plot_kws={'alpha': 0.2}, hue="drv")   
plt.show()

# %% [markdown]
# __Regression Plot__

# %%
# Plot Bars
plt.figure(figsize=(16,10), dpi= 80)
sns.pairplot(df_raw, kind="reg", diag_kind='kde', hue="drv")   
plt.show()

# %% [markdown]
# ## 4.4. Trellis Chart or Facet Grid
#
# ### Trellis Chart or Facet Grid
#
# While working on a project, sometimes you wish to see multiple plots in a single frame. A single plot can't be used and the multiple plots should be adjacent to each others.  That's where trellis chart comes to the rescue.
#
# A trellis plot can display various types of plots like scatter, bar, line etc.
#
# __When to use Trellis chart?__
#
# These plots are used to:
# - Analyze various plots in a single plot
#
#
# __Trellis Chart__
#
# Use `sns.FacetGrid` to plot Trellis chart.
#
# Task:
# - Analyze the relationship between displ and hwy for every class in mpg dataset

# %%
import pandas as pd

df_raw = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")
df_raw.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
# Plot Facets
plt.figure(figsize=(16,10), dpi= 80)
g = sns.FacetGrid(df_raw, col = "class")
g.map(plt.scatter, "displ", "hwy")
plt.show()

# %% [markdown]
# __Facet Grid with rows and columns both__
#
# You can use trellis charts for a combination of 2 categorical variables as well
#
# Task:
# - Analyze the relationship between displ and hwy for every class and drv in mpg dataset

# %%
# Plot Facets
plt.figure(figsize=(16,10), dpi= 80)
g = sns.FacetGrid(df_raw, col = "class", row = "drv")
g.map(plt.scatter, "displ", "hwy")
plt.show()

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>5. Plotting Relationship between Categorical vs Categorical variable</h2>
# </div>

# %% [markdown]
# If you wish to understand the relationship between two categorical variables you can use the **Mosaic Plots**

# %% [markdown]
# ## Mosaic Plot
#
# Mosaic Plot is used to visualize two or more categorical variables. It’s also called crosstabs or two-way table. As you can understand from the crosstabs, it is based on conditional probabilities
#
# __When to use mosaic plot ?__
#
# These plots are used to:
# - Understand the relation between categorical and categorical variables
#
# __Use Cases__
# - Analyze the relationship of gender and doing credit card fraud
# - Analyze the relationship of marital status and taking home loan
#
#
# Task:
# - Check the relationship between sex and survived in titanic dataset
#
# Use `mosaic` function from statsmodels.graphics.mosaicplot library to draw a mosaic plot

# %%
import pandas as pd
# Load Dataset
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['survived'] = ['Survived' if x == 1 else 'Died' for x in titanic['survived']]

# %%
# Compute the crosstable
crosstable=pd.crosstab(titanic['sex'],titanic['survived'])
crosstable
# Out:
# survived  Died  Survived
# sex
# female      81       233
# male       468       109

# %%
from statsmodels.graphics.mosaicplot import mosaic
mosaic(titanic, ['sex', 'survived']);

# %%
mosaic(titanic, ['class', 'survived']);

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>6. Time Series Plot</h2>
# </div>

# %% [markdown]
# If you wish to analyze the time series data,, you can use the following plots:
#
# - Line Plots
# - Line Plots with multiple lines
# - Line Plots with secondary axis
# - Autocorrelation Plot
# - Time Series Seasonal Plots
#     - Multi-Line chart
#     - The monthly and yearly bar chart
#
# ## 6.1 Line Plot
#
# Line chart or line plot or line graph represents various points called markers by connecting them by straight lines.
#
# It is the most basic and widely used visualization plot especially while working with time series data
#
#
# __When to use line plot?__
#
# Line plots are used to:
# - Represent the pattern or trend in the data
# - Represent the relation between two variables
# - Represent the change over time
#
# __Various types of line plot__
# - Single line plot
# - Multiple line plot
# - Dual axis line plot
#
# __Use Cases__
# - Analyze the stock prices over time
# - Analyze the sales over time
# - Analyze the effect of promotions on the sales
# - Find the pattern in COVID-19 cases over time
#
# __Single Line Plot__
# When you have only one y variable, use single line plot
#
# Task:
# - To analyze the personal savings rate over time

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import Data
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/economics.csv")
df.head()
# Out:
#          date    pce     pop  psavert  uempmed  unemploy
# 0  1967-07-01  507.4  198712     12.5      4.5      2944
# 1  1967-08-01  510.5  198911     12.5      4.7      2945
# 2  1967-09-01  516.3  199113     11.7      4.6      2958
# 3  1967-10-01  512.9  199311     12.5      4.9      3143
# 4  1967-11-01  518.1  199498     12.5      4.7      3066

# %% [markdown]
# Date is the x variable and psavert is the y variable. Let's store these in variables x and y

# %%
# Store the values in variables x and y
x = df['date']; y = df['psavert']

# %% [markdown]
# Now let's draw the line plot

# %%
# Draw Plot
plt.figure(figsize=(16,10), dpi= 80)
plt.plot(x, y, color='tab:red')

# Decoration
plt.title('Personal Savings Rate', fontsize=20)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Personal Savings Rate', fontsize=12)
plt.xticks(np.arange(0, len(x), 60))

plt.show()

# %% [markdown]
# ## 6.3. Dual Axis Line Plot
#
# When you want to analyze the effect of one variable on another over time, use dual axis line plot
#
# Task:
# - To analyze the effect of unemployement rate on the personal savings rate over time

# %%
# Store the values in variables x, y1 and y2
x = df['date']; y1 = df['psavert']; y2 = df['unemploy']

# %% [markdown]
# Now let's draw the line plot

# %%
# Plot Line1 (Left Y Axis)
fig, ax1 = plt.subplots(1,1,figsize=(16,9), dpi= 80)
ax1.plot(x, y1, color='tab:red')

# Plot Line2 (Right Y Axis)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(x, y2, color='tab:blue')

# Decorations
# ax1 (left Y axis)
ax1.set_xlabel('Year', fontsize=20)
ax1.tick_params(axis='x', rotation=0, labelsize=12)
ax1.set_ylabel('Personal Savings Rate', color='tab:red', fontsize=20)
ax1.tick_params(axis='y', rotation=0, labelcolor='tab:red' )
ax1.grid(alpha=.4)

# ax2 (right Y axis)
ax2.set_ylabel("# Unemployed (1000's)", color='tab:blue', fontsize=20)
ax2.tick_params(axis='y', labelcolor='tab:blue')
ax2.set_xticks(np.arange(0, len(x), 60))
# ax2.set_xticklabels(x[::60], rotation=90, fontdict={'fontsize':10})
ax2.set_title("Personal Savings Rate vs Unemployed: Plotting in Secondary Y Axis", fontsize=22)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 6.4. Autocorrelation and Partial Autocorrelation Plots
#
# The Autocorrelation plot shows the correlation of the time series with its own lags. Each vertical line (on the autocorrelation plot) represents the correlation between the series and its lag starting from lag 0. The blue shaded region in the plot is the significance level. Those lags that lie above the blue line are the significant lags
#
#
# __When to use ACF and PACF plot?__
#
# These plots are used to:
# - Compute the correlation of the time series with it's own lag
# - Compute the MA(d) component in ARIMA modelling
#
# Task:
# - To compute the Autocorrelation and Partial Autocorrelation of the number of visitors in Air Passengers data

# %%
# Import Data
df = pd.read_csv('https://github.com/selva86/datasets/raw/master/AirPassengers.csv')
df.head()
# Out:
#          date  value
# 0  1949-01-01    112
# 1  1949-02-01    118
# 2  1949-03-01    132
# 3  1949-04-01    129
# 4  1949-05-01    121

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Draw Plot
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(16,6), dpi= 80)
plot_acf(df.value.tolist(), ax=ax1, lags=50)
plot_pacf(df.value.tolist(), ax=ax2, lags=20)

# Decorate
# lighten the borders
ax1.spines["top"].set_alpha(.3); ax2.spines["top"].set_alpha(.3)
ax1.spines["bottom"].set_alpha(.3); ax2.spines["bottom"].set_alpha(.3)
ax1.spines["right"].set_alpha(.3); ax2.spines["right"].set_alpha(.3)
ax1.spines["left"].set_alpha(.3); ax2.spines["left"].set_alpha(.3)

# font size of tick labels
ax1.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)
plt.show()

# %% [markdown]
# ## 6.4 Time Series Seasonal Plots
#
# Time series seasonal plots are used to analyze the data at seasonal levels. You can use various types of plots:
# - Multi-Line chart
# - The monthly and yearly bar chart
#
# __When to use TS seasonal plot?__
#
# These plots are used to:
# - Analyze the data at seasonal levels
# - Compare the time series value at various years levels for same month/week etc
#
# __Various types of TS seasonal plot__
# - Multi-Line chart
# - The monthly and yearly bar chart
#
# __Use Cases__
# - Analyze the stock prices for every january over years
# - Analyze the sales for every january over years
#
#
# ### Line Plot with multiple lines
#
# When you want to analyze multiple time series at the same time. Ex. sales of multiple cars over years
#
# Task:
# - To analyze the sales of various car companies over years

# %%
car_sale_df = pd.read_csv("car_sales.csv")
car_sale_df
# Out:
#            Date  Sales_Audi  Sales_BMW
# 0    01/01/2011        1055       1581
# 1    01/02/2011        1257       1576
# 2    01/03/2011        1398       1425
# 3    01/04/2011        1146       1218
# 4    01/05/2011        1027       1384
# ..          ...         ...        ...
# 115  01/08/2020         300        470
# 116  01/09/2020         352        394
# 117  01/10/2020         289        430
# 118  01/11/2020         226        455
# 119  01/12/2020         213        342
#
# [120 rows x 3 columns]

# %%
car_sale_df['Date'] = pd.to_datetime(car_sale_df['Date'], format='%d/%m/%Y', errors='coerce')

# %%
# Draw Plot
plt.figure(figsize=(16,10), dpi= 80)
plt.plot(car_sale_df['Date'], car_sale_df['Sales_Audi'], color='tab:red', label='Audi')
plt.plot(car_sale_df['Date'], car_sale_df['Sales_BMW'], color='tab:blue', label='BMW')

# Decoration
plt.title('Audi vs BMW Sales', fontsize=20)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Sales Volume', fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# ### Monthly and Yearly Box Plot

# %%
import datetime
car_sale_df['Month'] = car_sale_df.Date.dt.month
car_sale_df['Year'] = car_sale_df.Date.dt.year
car_sale_df.head()
# Out:
#         Date  Sales_Audi  Sales_BMW  Month  Year
# 0 2011-01-01        1055       1581      1  2011
# 1 2011-02-01        1257       1576      2  2011
# 2 2011-03-01        1398       1425      3  2011
# 3 2011-04-01        1146       1218      4  2011
# 4 2011-05-01        1027       1384      5  2011

# %%
# Draw Plot
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(16,6), dpi= 80)
sns.boxplot(x='Month', y='Sales_BMW', data=car_sale_df, notch=False, ax=ax1)
sns.boxplot(x='Year', y='Sales_BMW', data=car_sale_df, notch=False, ax=ax2)

# # Decorate
ax1.title.set_text('Monthly Sales')
ax2.title.set_text('Yearly Sales')
plt.show()

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>7. Waterfall Chart and 3D Plots</h2>
# </div>

# %% [markdown]
# ## 7.1 Waterfall Chart
#
# Waterfall chart is a 2D plot that is used to understand the effects of adding positive or negative values over time or over multiple steps or a variable. Waterfall chart is frequently used in financial analysis to understand the gain and loss contributions of multiple factors over a particular asset.
#
#
# __When to use waterfall plot?__
#
# These plots are used to:
# - Represent how a starting value changes over time and becomes a final value
#
# __Use Cases__
# - Calculate net profit considering all revenue and investments
#
# Use `waterfall_chart` function to draw a waterfall chart
#
# Task:
# - To find the net profit

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import Data
index = ['sales','returns','credit fees','rebates','late charges','shipping']
data = {'amount': [350000,-30000,-7500,-25000,95000,-7000]}
df = pd.DataFrame(data=data,index=index)
df.head()
# Out:
#               amount
# sales         350000
# returns       -30000
# credit fees    -7500
# rebates       -25000
# late charges   95000

# %%
# !pip install waterfallcharts
import waterfall_chart

# %%
category = ['sales','returns','credit fees','rebates','late charges','shipping']
amount   = [350000,-30000,-7500,-25000,95000,-7000]

# %%
# Draw Plot
waterfall_chart.plot(category, amount)
plt.title('Waterfall Chart', fontsize = 20)
plt.xlabel('Çategory', fontsize = 12)
plt.ylabel('Amount', fontsize = 12)
plt.show()

# %% [markdown]
# ## 7.2. 3D Chart
#
# 2-D plots are fine when you deal with smaller dimensions of data, but whe you deal with higher dimensions, it's better to use 3-D plots.
# You can draw almost all the plots you learnt earlier in this section in 3-D.
#
# Initially matplotlib was designed to draw only 2-D plots. Later on **mplot3D** toolkit was developed to draw 3-D plot.
#
# Use `mplot3d` toolkit to draw 3-D plots in python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %% [markdown]
# #### Draw an empty 3-D plot

# %%
fig = plt.figure(figsize = (12,8))
fig.gca(projection='3d')
# Out:
# <Axes3DSubplot:>

# %% [markdown]
# #### Draw a 3-D line plot

# %%
# Create Data for parametric curve 
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)

# %%
# Draw Plot
fig = plt.figure(figsize = (12,8))
fig.gca(projection='3d')
plt.plot(x, y, z, label='parametric curve')
plt.legend()
plt.title('3D Parametric Curve', fontsize = 20)
plt.show()

# %% [markdown]
# #### Draw a 3-D scatter plot

# %%
# Draw Plot
fig = plt.figure(figsize = (12,8))
fig.gca(projection='3d')
plt.scatter(x, y, z, label='parametric curve')
plt.legend()
plt.title('3D Parametric Curve', fontsize = 20)
plt.show()

# %% [markdown]
# 1. Useful Pandas Plots Link: https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
# 2. Data Analysis Plots (matplotlib): https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/
